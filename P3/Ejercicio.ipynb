# %% [markdown]
# ##
#
# Despues de hablar con el profe matthieu, vamos a utilizar el dataset del grupo 1, porque los datos del dataset del grupo 10 estaban raros.
#
# 1) Predecir nivel de contaminacion y alerta

# %% [markdown]
# ### Pregunta 1
